# %%
# %sql
drop volume if exists yellow_taxi_for_project.default.data;
drop schema if exists yellow_taxi_for_project.default;
drop catalog if exists yellow_taxi_for_project;

# %%
spark.sql("CREATE catalog if not exists NY_Taxi MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragertkgqhhy66nu6.dfs.core.windows.net/1290381263006333'")

# %%
spark.sql("create schema if not exists NY_Taxi.Data")
spark.sql("create schema if not exists NY_Taxi.Bronze")
spark.sql("create schema if not exists NY_Taxi.Silver")
spark.sql("create schema if not exists NY_Taxi.Gold")

# %%
spark.sql("show schemas in NY_Taxi").display()

# %%
spark.sql("create volume if not exists NY_Taxi.data.source_files")

# %%
spark.sql("show volumes in NY_Taxi.data").display()

# %%
# removing all files and folders within volume
for item in dbutils.fs.ls("/Volumes/ny_taxi/data/source_files/"):
    dbutils.fs.rm(item.path, recurse=True)
