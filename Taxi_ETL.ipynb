# %%
df = spark.read.format("parquet").load("/Volumes/yellow_taxi_for_project/default/data/yellow_tripdata_2025-01.parquet")
display(df.limit(5))

# %%
df_zone_lookup = spark.read.format("csv").options(header=True).load("/Volumes/yellow_taxi_for_project/default/data/taxi_zone_lookup.csv")
display(df_zone_lookup.limit(5))
